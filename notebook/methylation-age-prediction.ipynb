# %% [markdown]
# # Methylation Age Prediction

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv('../data/final_methylation.csv')
df
# Out:
#     Unnamed: 0  cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# 0    GSM401538    0.623261    0.933737    0.784065    0.230605    0.856642
# 1    GSM401539    0.511191    0.947231    0.783920    0.144698    0.821330
# 2    GSM401540    0.563197    0.937874    0.897161    0.149871    0.819246
# 3    GSM401541    0.540890    0.936387    0.827485    0.142597    0.748252
# 4    GSM401542    0.534855    0.948110    0.881682    0.160029    0.811866
# ..         ...         ...         ...         ...         ...         ...
# 267  GSM765875    0.326400    0.911226    0.835002    0.248932    0.826605
# 268  GSM765876    0.308539    0.902355    0.827540    0.287357    0.795463
# 269  GSM765877    0.345696    0.897806    0.833040    0.283961    0.823329
# 270  GSM765878    0.288118    0.885518    0.819670    0.287034    0.827616
# 271  GSM765879    0.333430    0.916312    0.822063    0.256283    0.801290
#
#      cg00000289  cg00000292  cg00000321  cg00000363  ...  rs798149  rs845016  \
# 0      0.618541    0.617381    0.715755    0.196520  ...  0.020533  0.923961
# 1      0.361362    0.685630    0.630844    0.100388  ...  0.031023  0.899096
# 2      0.373199    0.700967    0.634477    0.100342  ...  0.447214  0.443945
# 3      0.360464    0.683001    0.590817    0.126747  ...  0.961344  0.059906
# 4      0.394502    0.703743    0.601542    0.103967  ...  0.444406  0.048936
# ..          ...         ...         ...         ...  ...       ...       ...
# 267    0.584044    0.609397    0.320528    0.289650  ...  0.454957  0.310766
# 268    0.569178    0.579523    0.315771    0.278816  ...  0.456454  0.504260
# 269    0.549042    0.588727    0.337625    0.266155  ...  0.365728  0.557258
# 270    0.531049    0.599105    0.350152    0.240955  ...  0.367743  0.572944
# 271    0.577958    0.607616    0.284556    0.248361  ...  0.709726  0.476535
#
#      rs877309  rs9292570  rs9363764  rs939290  rs951295  rs966367  rs9839873  \
# 0    0.963812   0.945121   0.947018  0.958767  0.947758  0.555746   0.946585
# 1    0.937467   0.930882   0.927759  0.943658  0.952008  0.564649   0.920854
# 2    0.020165   0.549681   0.049844  0.949976  0.562691  0.534222   0.920399
# 3    0.656052   0.076498   0.611128  0.950231  0.538780  0.915197   0.058580
# 4    0.957816   0.515390   0.043295  0.945776  0.558405  0.527386   0.071133
# ..        ...        ...        ...       ...       ...       ...        ...
# 267  0.505813   0.674645   0.680495  0.420753  0.506520  0.602847   0.866066
# 268  0.487622   0.705018   0.488612  0.429429  0.291379  0.621844   0.902896
# 269  0.626746   0.487961   0.710769  0.948284  0.620657  0.598934   0.788166
# 270  0.285246   0.158870   0.409991  0.633655  0.405652  0.397576   0.710943
# 271  0.521727   0.609970   0.407504  0.632787  0.616917  0.312781   0.763659
#
#      Age
# 0     20
# 1     44
# 2     23
# 3     38
# 4     66
# ..   ...
# 267   91
# 268   89
# 269   89
# 270   90
# 271   90
#
# [272 rows x 480609 columns]

# %%
# Split the data into features and target
X = df.drop(columns=['Unnamed: 0', 'Age'])
y = df['Age']

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train a elastic net model
from sklearn.linear_model import ElasticNet

model = ElasticNet(alpha=0.5)
model.fit(X_train, y_train)
# Out:
# /Users/garrinshieh/PycharmProjects/methylation-age-prediction/venv/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.507e+04, tolerance: 1.535e+01
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet(alpha=0.5)

# %%
# Evaluate the model
from sklearn.metrics import root_mean_squared_error, mean_absolute_error

y_pred = model.predict(X_test)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse, mae
# Out:
# (np.float64(1.3798960748014454e+36), np.float64(2.6515336756082273e+35))
